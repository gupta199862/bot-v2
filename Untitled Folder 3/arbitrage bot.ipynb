# %%
import ccxt

# %%
# coding=utf-8

import ccxt

hitbtc = ccxt.hitbtc({'verbose': True})
bitmex = ccxt.bitmex()
huobi  = ccxt.huobi()
# Out:
# Request: GET http://api.hitbtc.com/api/1/public/symbols {'Accept-Encoding': 'gzip, deflate', 'User-Agent': 'python-requests/2.18.4'} None
#
# Response: GET http://api.hitbtc.com/api/1/public/symbols 200 {'Content-Type': 'application/json; charset=utf-8', 'Connection': 'keep-alive', 'Date': 'Fri, 25 May 2018 14:06:06 GMT', 'Content-Length': '8144', 'Server': 'nginx', 'Age': '0', 'Content-Encoding': 'gzip'} {"symbols":[{"symbol":"BCNBTC","step":"0.0000000001","lot":"100","currency":"BTC","commodity":"BCN","takeLiquidityRate":"0.001","provideLiquidityRate":"-0.0001"},{"symbol":"BTCUSD","step":"0.01","lot":"0.01","currency":"USD","commodity":"BTC","takeLiquidityRate":"0.001","provideLiquidityRate":"-0.0001"},{"symbol":"DASHBTC","step":"0.000001","lot":"0.001","currency":"BTC","commodity":"DASH","takeLiquidityRate":"0.001","provideLiquidityRate":"-0.0001"},{"symbol":"DOGEBTC","step":"0.000000001","lot":"1000","currency":"BTC","commodity":"DOGE","takeLiquidityRate":"0.001","provideLiquidityRate":"-0.0001"},{"symbol":"DOGEUSD","step":"0.000001","lot":"10","currency":"USD","commodity":"DOGE","takeLiquidityRate":"0.001","provideLiquidityRate":"-0.0001"},{"symbol":"DSHBTC","step":"0.000000001","lot":"1","currency":"BTC","commodity":"DSH","takeLiquidityRate":"0.001","provideLiquidityRate":"-0.0001"},{"symbol":"EMCBTC","step":"0.00000001","lot":"0.1","currency":"BTC","commodity":"EMC","takeLiquidityRate":"0.001","provideLiquidityRate":"-0.0001"},{"symbol":"ETHBTC","step":"0.000001","lot":"0.001","currency":"BTC","commodity":"ETH","takeLiquidityRate":"0.001","provideLiquidityRate":"-0.0001"},{"symbol":"FCNBTC","step":"0.000001","lot":"0.01","currency":"BTC","commodity":"FCN","takeLiquidityRate":"0.001","provideLiquidityRate":"-0.0001"},{"symbol":"LSKBTC","step":"0.0000001","lot":"0.01","currency":"BTC","commodity":"LSK","takeLiquidityRate":"0.001","provideLiquidityRate":"-0.0001"},{"symbol":"LTCBTC","step":"0.00001","lot":"0.1","currency":"BTC","commodity":"LTC","takeLiquidityRate":"0.001","provideLiquidityRate":"-0.0001"},{"symbol":"LTCUSD","step":"0.001","lot":"0.1","currency":"USD","commodity":"LTC","takeLiquidityRate":"0.001","provideLiquidityRate":"-0.0001"},{"symbol":"NXTBTC","step":"0.00000001","lot":"1","currency":"BTC","commodity":"NXT","takeLiquidityRate":"0.001","provideLiquidityRate":"-0.0001"},{"symbol":"QCNBTC","step":"0.000001","lot":"0.01","currency":"BTC","commodity":"QCN","takeLiquidityRate":"0.001","provideLiquidityRate":"-0.0001"},{"symbol":"SBDBTC","step":"0.00001","lot":"0.001","currency":"BTC","commodity":"SBD","takeLiquidityRate":"0.001","provideLiquidityRate":"-0.0001"},{"symbol":"SCBTC","step":"0.000000001","lot":"100","currency":"BTC","commodity":"SC","takeLiquidityRate":"0.001","provideLiquidityRate":"-0.0001"},{"symbol":"STEEMBTC","step":"0.00001","lot":"0.001","currency":"BTC","commodity":"STEEM","takeLiquidityRate":"0.001","provideLiquidityRate":"-0.0001"},{"symbol":"XDNBTC","step":"0.0000000001","lot":"100","currency":"BTC","commodity":"XDN","takeLiquidityRate":"0.001","provideLiquidityRate":"-0.0001"},{"symbol":"XEMBTC","step":"0.00000001","lot":"1","currency":"BTC","commodity":"XEM","takeLiquidityRate":"0.001","provideLiquidityRate":"-0.0001"},{"symbol":"XMRBTC","step":"0.000001","lot":"0.01","currency":"BTC","commodity":"XMR","takeLiquidityRate":"0.001","provideLiquidityRate":"-0.0001"},{"symbol":"ARDRBTC","step":"0.000000001","lot":"1","currency":"BTC","commodity":"ARDR","takeLiquidityRate":"0.001","provideLiquidityRate":"-0.0001"},{"symbol":"ZECBTC","step":"0.000001","lot":"0.001","currency":"BTC","commodity":"ZEC","takeLiquidityRate":"0.001","provideLiquidityRate":"-0.0001"},{"symbol":"WAVESBTC","step":"0.0000001","lot":"0.01","currency":"BTC","commodity":"WAVES","takeLiquidityRate":"0.001","provideLiquidityRate":"-0.0001"},{"symbol":"MAIDBTC","step":"0.00000001","lot":"1","currency":"BTC","commodity":"MAID","takeLiquidityRate":"0.001","provideLiquidityRate":"-0.0001"},{"symbol":"AMPBTC","step":"0.00000001","lot":"0.1","currency":"BTC","commodity":"AMP","takeLiquidityRate":"0.001","provideLiquidityRate":"-0.0001"},{"symbol":"BUSBTC","step":" ...
# hitbtc {'DAXT/ETH': {'baseId': 'DAXT', 'base': 'DAXT', 'limits': {'amount': {'min': 10.0, 'max': None}, 'cost': {'min': None, 'max': None}, 'price': {'min': 1e-06, 'max': None}}, 'id': 'DAXTETH', 'symbol': 'DAXT/ETH', 'step': 1e-06, 'active': True, 'quote': 'ETH', 'tierBased': False, 'taker': 0.001, 'fee_loaded': False, 'maker': -0.0001, 'info': {'step': '0.000001', 'commodity': 'DAXT', 'symbol': 'DAXTETH', 'provideLiquidityRate': '-0.0001', 'lot': '10', 'takeLiquidityRate': '0.001', 'currency': 'ETH'}, 'quoteId': 'ETH', 'lot': 10.0, 'percentage': True, 'precision': {'amount': 0, 'price': 6}}, 'BANCA/USDT': {'baseId': 'BANCA', 'base': 'BANCA', 'limits': {'amount': {'min': 1000.0, 'max': None}, 'cost': {'min': None, 'max': None}, 'price': {'min': 1e-07, 'max': None}}, 'id': 'BANCAUSD', 'symbol': 'BANCA/USDT', 'step': 1e-07, 'active': True, 'quote': 'USDT', 'tierBased': False, 'taker': 0.001, 'fee_loaded': False, 'maker': -0.0001, 'info': {'step': '0.0000001', 'commodity': 'BANCA', 'symbol': 'BANCAUSD', 'provideLiquidityRate': '-0.0001', 'lot': '1000', 'takeLiquidityRate': '0.001', 'currency': 'USD'}, 'quoteId': 'USD', 'lot': 1000.0, 'percentage': True, 'precision': {'amount': 0, 'price': 7}}, 'BCPT/USDT': {'baseId': 'BCPT', 'base': 'BCPT', 'limits': {'amount': {'min': 10.0, 'max': None}, 'cost': {'min': None, 'max': None}, 'price': {'min': 1e-05, 'max': None}}, 'id': 'BCPTUSDT', 'symbol': 'BCPT/USDT', 'step': 1e-05, 'active': True, 'quote': 'USDT', 'tierBased': False, 'taker': 0.001, 'fee_loaded': False, 'maker': -0.0001, 'info': {'step': '0.00001', 'commodity': 'BCPT', 'symbol': 'BCPTUSDT', 'provideLiquidityRate': '-0.0001', 'lot': '10', 'takeLiquidityRate': '0.001', 'currency': 'USD'}, 'quoteId': 'USD', 'lot': 10.0, 'percentage': True, 'precision': {'amount': 0, 'price': 5}}, 'CVC/USDT': {'baseId': 'CVC', 'base': 'CVC', 'limits': {'amount': {'min': 0.01, 'max': None}, 'cost': {'min': None, 'max': None}, 'price': {'min': 0.0001, 'max': None}}, 'id': 'CVCUSD', 'symbol': 'CVC/USDT', 'step': 0.0001, 'active': True, 'quote': 'USDT', 'tierBased': False, 'taker': 0.001, 'fee_loaded': False, 'maker': -0.0001, 'info': {'step': '0.0001', 'commodity': 'CVC', 'symbol': 'CVCUSD', 'provideLiquidityRate': '-0.0001', 'lot': '0.01', 'takeLiquidityRate': '0.001', 'currency': 'USD'}, 'quoteId': 'USD', 'lot': 0.01, 'percentage': True, 'precision': {'amount': 2, 'price': 4}}, 'SUR/USDT': {'baseId': 'SUR', 'base': 'SUR', 'limits': {'amount': {'min': 1.0, 'max': None}, 'cost': {'min': None, 'max': None}, 'price': {'min': 0.0001, 'max': None}}, 'id': 'SURUSD', 'symbol': 'SUR/USDT', 'step': 0.0001, 'active': True, 'quote': 'USDT', 'tierBased': False, 'taker': 0.001, 'fee_loaded': False, 'maker': -0.0001, 'info': {'step': '0.0001', 'commodity': 'SUR', 'symbol': 'SURUSD', 'prov
, 0.06], [0.00017, 26.327], [0.000176, 92.038], [0.000177, 33.534], [0.000178, 0.127], [0.000179, 47.205], [0.00018, 681.872], [0.000184, 20.0], [0.000186, 333.897], [0.000187, 0.001], [0.000189, 0.053], [0.00019, 542.082], [0.000191, 914.607], [0.000192, 360.0], [0.000193, 125.0], [0.000194, 0.05], [0.000195, 580.012], [0.000198, 231.315], [0.000199, 28.498], [0.0002, 2187.735], [0.000201, 200.0], [0.000205, 616.004], [0.000206, 526.939], [0.000208, 124.293], [0.000209, 50.048], [0.000212, 200.0], [0.000218, 2687.738], [0.000219, 0.046], [0.00022, 18.2], [0.000221, 549.0], [0.000223, 0.001], [0.000224, 820.258], [0.000226, 15.0], [0.000227, 20.0], [0.000229, 50.044], [0.00023, 710.3], [0.000238, 48.429], [0.000239, 600.042], [0.00024, 1228.38], [0.000242, 175.0], [0.000244, 174.825], [0.000247, 231.341], [0.000248, 20.0], [0.000249, 40.041], [0.00025, 649.088], [0.000259, 15.039], [0.00026, 496.508], [0.000262, 37.997], [0.000263, 150.0], [0.000268, 38.362], [0.000269, 0.038], [0.000271, 475.0], [0.000273, 1578.925], [0.000278, 30.769], [0.000279, 100.556], [0.00028, 2403.194], [0.000281, 3000.0], [0.000284, 0.001], [0.000286, 8.716], [0.000288, 2170.255], [0.000289, 15.035], [0.00029, 50.0], [0.000299, 30.034], [0.0003, 13390.727], [0.000302, 10.873], [0.000303, 495.5], [0.000309, 0.033], [0.00031, 0.179], [0.000319, 0.032], [0.00032, 1994.265], [0.000329, 0.03 ...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/python-vlenv/keras-tf/lib/python3.5/site-packages/ccxt/base/exchange.py in fetch(self, url, method, headers, body)
#     364             self.logger.debug("%s %s, Response: %s %s %s", method, url, response.status_code, response.headers, self.last_http_response)
# --> 365             response.raise_for_status()
#     366
#
# ~/python-vlenv/keras-tf/lib/python3.5/site-packages/requests/models.py in raise_for_status(self)
#     934         if http_error_msg:
# --> 935             raise HTTPError(http_error_msg, response=self)
#     936
#
# HTTPError: 403 Client Error: Forbidden for url: http://api.huobi.com/staticmarket/detail_ltc_json.js
#
# During handling of the above exception, another exception occurred:
#
# ExchangeNotAvailable                      Traceback (most recent call last)
# <ipython-input-5-e49331541fcb> in <module>()
#      16 print(hitbtc.fetch_order_book(hitbtc.symbols[0]))
#      17 #print(bitmex.fetch_ticker('BTC/USD'))
# ---> 18 print(huobi.fetch_trades('LTC/CNY'))
#      19
#      20
#
# ~/python-vlenv/keras-tf/lib/python3.5/site-packages/ccxt/huobi.py in fetch_trades(self, symbol, since, limit, params)
#     163         response = getattr(self, method)(self.extend({
#     164             'id': market['id'],
# --> 165         }, params))
#     166         return self.parse_trades(response['trades'], market, since, limit)
#     167
#
# ~/python-vlenv/keras-tf/lib/python3.5/site-packages/ccxt/huobi.py in request(self, path, api, method, params, headers, body)
#     234
#     235     def request(self, path, api='trade', method='GET', params={}, headers=None, body=None):
# --> 236         response = self.fetch2(path, api, method, params, headers, body)
#     237         if 'status' in response:
#     238             if response['status'] == 'error':
#
# ~/python-vlenv/keras-tf/lib/python3.5/site-packages/ccxt/base/exchange.py in fetch2(self, path, api, method, params, headers, body)
#     302         self.lastRestRequestTimestamp = self.milliseconds()
#     303         request = self.sign(path, api, method, params, headers, body)
# --> 304         return self.fetch(request['url'], request['method'], request['headers'], request['body'])
#     305
#     306     def request(self, path, api='public', method='GET', params={}, headers=None, body=None):
#
# ~/python-vlenv/keras-tf/lib/python3.5/site-packages/ccxt/base/exchange.py in fetch(self, url, method, headers, body)
#     376         except HTTPError as e:
#     377             self.handle_errors(response.status_code, response.reason, url, method, self.last_response_headers, self.last_http_response)
# --> 378             self.handle_rest_errors(e, response.status_code, self.last_http_response, url, method)
#     379             self.raise_error(ExchangeError, url, method, e, self.last_http_response)
#     380
#
# ~/python-vlenv/keras-tf/lib/python3.5/site-packages/ccxt/base/exchange.py in handle_rest_errors(self, exception, http_status_code, response, url, method)
#     405             error = AuthenticationError
#     406         if error:
# --> 407             self.raise_error(error, url, method, exception if exception else http_status_code, response)
#     408
#     409     def handle_rest_response(self, response, url, method='GET', headers=None, body=None):
#
# ~/python-vlenv/keras-tf/lib/python3.5/site-packages/ccxt/base/exchange.py in raise_error(self, exception_type, url, method, error, details)
#     287             error = str(error)
#     288         output = ' '.join([self.id] + [var for var in (url, method, error, details) if var is not None])
# --> 289         raise exception_type(output)
#     290
#     291     def throttle(self):
#
# ExchangeNotAvailable: huobi http://api.huobi.com/staticmarket/detail_ltc_json.js GET 403 Client Error: Forbidden for url: http://api.huobi.com/staticmarket/detail_ltc_json.js <html>
# <head><title>403 Forbidden</title></head>
# <body bgcolor="white">
# <center><h1>403 Forbidden</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>

# %%
okcoin = ccxt.okcoinusd ()
markets = okcoin.load_markets ()
print (okcoin.id, markets)
# Out:
# {'ETC/USD': {'baseId': 'etc', 'base': 'ETC', 'limits': {'amount': {'min': 0.1, 'max': None}, 'cost': {'min': 0.001, 'max': None}, 'price': {'min': 0.01, 'max': None}}, 'id': 'etc_usd', 'spot': True, 'symbol': 'ETC/USD', 'baseNumericId': 4, 'active': True, 'quote': 'USD', 'taker': 0.002, 'fee_loaded': False, 'future': False, 'maker': 0.002, 'info': {'isMarginOpen': False, 'marginRiskPreRatio': 0, 'listDisplay': 0, 'marketFrom': 39, 'symbol': 'etc_usd', 'quoteIncrement': '0.01', 'mergeTypes': {}, 'maxMarginLeverage': 0, 'minTradeSize': 0.1, 'tradingMode': 3, 'quoteCurrency': 3, 'marginRiskRatio': 0, 'maxPriceDigit': 2, 'sort': 3, 'maxSizeDigit': 4, 'continuousSwitchTime': {}, 'collect': '0', 'callNoCancelSwitchTime': 1526290902000, 'productId': 1, 'quotePrecision': 4, 'online': 1, 'baseCurrency': 4}, 'quoteId': 'usd', 'lot': 0.0001, 'type': 'spot', 'percentage': True, 'precision': {'amount': 4, 'price': 2}, 'quoteNumericId': 3}, 'BTC/USD': {'baseId': 'btc', 'base': 'BTC', 'limits': {'amount': {'min': 0.01, 'max': None}, 'cost': {'min': 0.0001, 'max': None}, 'price': {'min': 0.01, 'max': None}}, 'id': 'btc_usd', 'spot': True, 'symbol': 'BTC/USD', 'baseNumericId': 0, 'active': True, 'quote': 'USD', 'taker': 0.002, 'fee_loaded': False, 'future': False, 'maker': 0.002, 'info': {'isMarginOpen': True, 'marginRiskPreRatio': 1.3, 'listDisplay': 0, 'marketFrom': 0, 'symbol': 'btc_usd', 'quoteIncrement': '0.01', 'mergeTypes': {}, 'maxMarginLeverage': 3, 'minTradeSize': 0.01, 'tradingMode': 3, 'quoteCurrency': 3, 'marginRiskRatio': 1.1, 'maxPriceDigit': 2, 'sort': 0, 'maxSizeDigit': 4, 'continuousSwitchTime': {}, 'collect': '0', 'callNoCancelSwitchTime': 1526290902000, 'productId': 16, 'quotePrecision': 4, 'online': 1, 'baseCurrency': 0}, 'quoteId': 'usd', 'lot': 0.0001, 'type': 'spot', 'percentage': True, 'precision': {'amount': 4, 'price': 2}, 'quoteNumericId': 3}, 'LTC/USD': {'baseId': 'ltc', 'base': 'LTC', 'limits': {'amount': {'min': 0.1, 'max': None}, 'cost': {'min': 0.001, 'max': None}, 'price': {'min': 0.01, 'max': None}}, 'id': 'ltc_usd', 'spot': True, 'symbol': 'LTC/USD', 'baseNumericId': 1, 'active': True, 'quote': 'USD', 'taker': 0.002, 'fee_loaded': False, 'future': False, 'maker': 0.002, 'info': {'isMarginOpen': False, 'marginRiskPreRatio': 0, 'listDisplay': 0, 'marketFrom': 3, 'symbol': 'ltc_usd', 'quoteIncrement': '0.01', 'mergeTypes': {}, 'maxMarginLeverage': 0, 'minTradeSize': 0.1, 'tradingMode': 3, 'quoteCurrency': 3, 'marginRiskRatio': 0, 'maxPriceDigit': 2, 'sort': 1, 'maxSizeDigit': 4, 'continuousSwitchTime': {}, 'collect': '0', 'callNoCancelSwitchTime': 1526290902000, 'productId': 17, 'quotePrecision': 4, 'online': 1, 'baseCurrency': 1}, 'quoteId': 'usd', 'lot': 0.0001, 'type': 'spot', 'percentage': True, 'precision': {'amount': 4, 'price': 2}, 'quoteNumericId': 3}, 'ETH/USD': {'baseId': 'eth', 'base': 'ETH', 'limits': {'amount': {'min': 0.01, 'max': None}, 'cost': {'min': 0.0001, 'max': None}, 'price': {'min': 0.01, 'max': None}}, 'id': 'eth_usd', 'spot': True, 'symbol': 'ETH/USD', 'baseNumericId': 2, 'active': True, 'quote': 'USD', 'taker': 0.002, 'fee_loaded': False, 'future': False, 'maker': 0.002, 'info': {'isMarginOpen': True, 'marginRiskPreRatio': 1.3, 'listDisplay': 0, 'marketFrom': 36, 'symbol': 'eth_usd', 'quoteIncrement': '0.01', 'mergeTypes': {}, 'maxMarginLeverage': 3, 'minTradeSize': 0.01, 'tradingMode': 3, 'quoteCurrency': 3, 'marginRiskRatio': 1.1, 'maxPriceDigit': 2, 'sort': 2, 'maxSizeDigit': 4, 'continuousSwitchTime': {}, 'collect': '0', 'callNoCancelSwitchTime': 1526290902000, 'productId': 18, 'quotePrecision': 4, 'online': 1, 'baseCurrency': 2}, 'quoteId': 'usd', 'lot': 0.0001, 'type': 'spot', 'percentage': True, 'precision': {'amount': 4, 'price': 2}, 'quoteNumericId': 3}, 'BCH/USD': {'baseId': 'bch', 'base': 'BCH', 'limits': {'amount': {'min': 0.001, 'max': None}, 'cost': {'min': 1e-05, 'max': None}, 'price': {'min': 0.01, 'max': None}}, 'id': 'bch_usd', 'spot': True, 'symbol': 'BCH/USD', 'base ...

# %%
okcoin = ccxt.okcoinusd ()
markets = okcoin.load_markets ()
print (okcoin.id, markets)
# Out:
# okcoinusd {'ETC/USD': {'baseId': 'etc', 'base': 'ETC', 'limits': {'amount': {'min': 0.1, 'max': None}, 'cost': {'min': 0.001, 'max': None}, 'price': {'min': 0.01, 'max': None}}, 'id': 'etc_usd', 'spot': True, 'symbol': 'ETC/USD', 'baseNumericId': 4, 'active': True, 'quote': 'USD', 'taker': 0.002, 'fee_loaded': False, 'future': False, 'maker': 0.002, 'info': {'isMarginOpen': False, 'marginRiskPreRatio': 0, 'listDisplay': 0, 'marketFrom': 39, 'symbol': 'etc_usd', 'quoteIncrement': '0.01', 'mergeTypes': {}, 'maxMarginLeverage': 0, 'minTradeSize': 0.1, 'tradingMode': 3, 'quoteCurrency': 3, 'marginRiskRatio': 0, 'maxPriceDigit': 2, 'sort': 3, 'maxSizeDigit': 4, 'continuousSwitchTime': {}, 'collect': '0', 'callNoCancelSwitchTime': 1526290902000, 'productId': 1, 'quotePrecision': 4, 'online': 1, 'baseCurrency': 4}, 'quoteId': 'usd', 'lot': 0.0001, 'type': 'spot', 'percentage': True, 'precision': {'amount': 4, 'price': 2}, 'quoteNumericId': 3}, 'BTC/USD': {'baseId': 'btc', 'base': 'BTC', 'limits': {'amount': {'min': 0.01, 'max': None}, 'cost': {'min': 0.0001, 'max': None}, 'price': {'min': 0.01, 'max': None}}, 'id': 'btc_usd', 'spot': True, 'symbol': 'BTC/USD', 'baseNumericId': 0, 'active': True, 'quote': 'USD', 'taker': 0.002, 'fee_loaded': False, 'future': False, 'maker': 0.002, 'info': {'isMarginOpen': True, 'marginRiskPreRatio': 1.3, 'listDisplay': 0, 'marketFrom': 0, 'symbol': 'btc_usd', 'quoteIncrement': '0.01', 'mergeTypes': {}, 'maxMarginLeverage': 3, 'minTradeSize': 0.01, 'tradingMode': 3, 'quoteCurrency': 3, 'marginRiskRatio': 1.1, 'maxPriceDigit': 2, 'sort': 0, 'maxSizeDigit': 4, 'continuousSwitchTime': {}, 'collect': '0', 'callNoCancelSwitchTime': 1526290902000, 'productId': 16, 'quotePrecision': 4, 'online': 1, 'baseCurrency': 0}, 'quoteId': 'usd', 'lot': 0.0001, 'type': 'spot', 'percentage': True, 'precision': {'amount': 4, 'price': 2}, 'quoteNumericId': 3}, 'LTC/USD': {'baseId': 'ltc', 'base': 'LTC', 'limits': {'amount': {'min': 0.1, 'max': None}, 'cost': {'min': 0.001, 'max': None}, 'price': {'min': 0.01, 'max': None}}, 'id': 'ltc_usd', 'spot': True, 'symbol': 'LTC/USD', 'baseNumericId': 1, 'active': True, 'quote': 'USD', 'taker': 0.002, 'fee_loaded': False, 'future': False, 'maker': 0.002, 'info': {'isMarginOpen': False, 'marginRiskPreRatio': 0, 'listDisplay': 0, 'marketFrom': 3, 'symbol': 'ltc_usd', 'quoteIncrement': '0.01', 'mergeTypes': {}, 'maxMarginLeverage': 0, 'minTradeSize': 0.1, 'tradingMode': 3, 'quoteCurrency': 3, 'marginRiskRatio': 0, 'maxPriceDigit': 2, 'sort': 1, 'maxSizeDigit': 4, 'continuousSwitchTime': {}, 'collect': '0', 'callNoCancelSwitchTime': 1526290902000, 'productId': 17, 'quotePrecision': 4, 'online': 1, 'baseCurrency': 1}, 'quoteId': 'usd', 'lot': 0.0001, 'type': 'spot', 'percentage': True, 'precision': {'amount': 4, 'price': 2}, 'quoteNumericId': 3}, 'ETH/USD': {'baseId': 'eth', 'base': 'ETH', 'limits': {'amount': {'min': 0.01, 'max': None}, 'cost': {'min': 0.0001, 'max': None}, 'price': {'min': 0.01, 'max': None}}, 'id': 'eth_usd', 'spot': True, 'symbol': 'ETH/USD', 'baseNumericId': 2, 'active': True, 'quote': 'USD', 'taker': 0.002, 'fee_loaded': False, 'future': False, 'maker': 0.002, 'info': {'isMarginOpen': True, 'marginRiskPreRatio': 1.3, 'listDisplay': 0, 'marketFrom': 36, 'symbol': 'eth_usd', 'quoteIncrement': '0.01', 'mergeTypes': {}, 'maxMarginLeverage': 3, 'minTradeSize': 0.01, 'tradingMode': 3, 'quoteCurrency': 3, 'marginRiskRatio': 1.1, 'maxPriceDigit': 2, 'sort': 2, 'maxSizeDigit': 4, 'continuousSwitchTime': {}, 'collect': '0', 'callNoCancelSwitchTime': 1526290902000, 'productId': 18, 'quotePrecision': 4, 'online': 1, 'baseCurrency': 2}, 'quoteId': 'usd', 'lot': 0.0001, 'type': 'spot', 'percentage': True, 'precision': {'amount': 4, 'price': 2}, 'quoteNumericId': 3}, 'BCH/USD': {'baseId': 'bch', 'base': 'BCH', 'limits': {'amount': {'min': 0.001, 'max': None}, 'cost': {'min': 1e-05, 'max': None}, 'price': {'min': 0.01, 'max': None}}, 'id': 'bch_usd', 'spot': True, 'symbol': 'BCH/U ...

# %%
kraken = ccxt.kraken ()
kraken.load_markets ()
# Out:
# {'BCH/BTC': {'active': True,
#   'altname': 'BCHXBT',
#   'base': 'BCH',
#   'baseId': 'BCH',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'BCHXBT',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'BCHXBT',
#    'base': 'BCH',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 5,
#    'quote': 'XXBT'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 0.002},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 1e-05}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 5},
#   'quote': 'BTC',
#   'quoteId': 'XXBT',
#   'symbol': 'BCH/BTC',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'BCH/EUR': {'active': True,
#   'altname': 'BCHEUR',
#   'base': 'BCH',
#   'baseId': 'BCH',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'BCHEUR',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'BCHEUR',
#    'base': 'BCH',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 1,
#    'quote': 'ZEUR'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 0.002},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 0.1}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 1},
#   'quote': 'EUR',
#   'quoteId': 'ZEUR',
#   'symbol': 'BCH/EUR',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'BCH/USD': {'active': True,
#   'altname': 'BCHUSD',
#   'base': 'BCH',
#   'baseId': 'BCH',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'BCHUSD',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'BCHUSD',
#    'base': 'BCH',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 1,
#    'quote': 'ZUSD'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 0.002},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 0.1}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 1},
#   'quote': 'USD',
#   'quoteId': 'ZUSD',
#   'symbol': 'BCH/USD',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'BTC/CAD': {'active': True,
#   'altname': 'XBTCAD',
#   'base': 'BTC',
#   'baseId': 'XXBT',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'XXBTZCAD',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'XBTCAD',
#    'base': 'XXBT',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 1,
#    'quote': 'ZCAD'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 1e-08},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 0.1}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 1},
#   'quote': 'CAD',
#   'quoteId': 'ZCAD',
#   'symbol': 'BTC/CAD',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'BTC/EUR': {'active': True,
#   'altname': 'XBTEUR',
#   'base': 'BTC',
#   'baseId': 'XXBT',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'XXBTZEUR',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'XBTEUR',
#    'base': 'XXBT',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [2, 3, 4, 5],
#    'leverage_sell': [2, 3, 4, 5],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 1,
#    'quote': 'ZEUR'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 1e-08},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 0.1}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 1},
#   'quote': 'EUR',
#   'quoteId': 'ZEUR',
#   'symbol': 'BTC/EUR',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'BTC/GBP': {'active': True,
#   'altname': 'XBTGBP',
#   'base': 'BTC',
#   'baseId': 'XXBT',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'XXBTZGBP',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'XBTGBP',
#    'base': 'XXBT',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 1,
#    'quote': 'ZGBP'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 1e-08},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 0.1}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 1},
#   'quote': 'GBP',
#   'quoteId': 'ZGBP',
#   'symbol': 'BTC/GBP',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'BTC/JPY': {'active': True,
#   'altname': 'XBTJPY',
#   'base': 'BTC',
#   'baseId': 'XXBT',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'XXBTZJPY',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'XBTJPY',
#    'base': 'XXBT',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 0,
#    'quote': 'ZJPY'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 1e-08},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 1.0}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 0},
#   'quote': 'JPY',
#   'quoteId': 'ZJPY',
#   'symbol': 'BTC/JPY',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'BTC/USD': {'active': True,
#   'altname': 'XBTUSD',
#   'base': 'BTC',
#   'baseId': 'XXBT',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'XXBTZUSD',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'XBTUSD',
#    'base': 'XXBT',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [2, 3, 4, 5],
#    'leverage_sell': [2, 3, 4, 5],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 1,
#    'quote': 'ZUSD'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 1e-08},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 0.1}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 1},
#   'quote': 'USD',
#   'quoteId': 'ZUSD',
#   'symbol': 'BTC/USD',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'DASH/BTC': {'active': True,
#   'altname': 'DASHXBT',
#   'base': 'DASH',
#   'baseId': 'DASH',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'DASHXBT',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'DASHXBT',
#    'base': 'DASH',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 5,
#    'quote': 'XXBT'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 0.03},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 1e-05}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 5},
#   'quote': 'BTC',
#   'quoteId': 'XXBT',
#   'symbol': 'DASH/BTC',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'DASH/EUR': {'active': True,
#   'altname': 'DASHEUR',
#   'base': 'DASH',
#   'baseId': 'DASH',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'DASHEUR',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'DASHEUR',
#    'base': 'DASH',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 3,
#    'quote': 'ZEUR'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 0.03},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 0.001}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 3},
#   'quote': 'EUR',
#   'quoteId': 'ZEUR',
#   'symbol': 'DASH/EUR',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'DASH/USD': {'active': True,
#   'altname': 'DASHUSD',
#   'base': 'DASH',
#   'baseId': 'DASH',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'DASHUSD',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'DASHUSD',
#    'base': 'DASH',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 3,
#    'quote': 'ZUSD'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 0.03},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 0.001}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 3},
#   'quote': 'USD',
#   'quoteId': 'ZUSD',
#   'symbol': 'DASH/USD',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'EOS/BTC': {'active': True,
#   'altname': 'EOSXBT',
#   'base': 'EOS',
#   'baseId': 'EOS',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'EOSXBT',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'EOSXBT',
#    'base': 'EOS',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 7,
#    'quote': 'XXBT'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 3.0},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 1e-07}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 7},
#   'quote': 'BTC',
#   'quoteId': 'XXBT',
#   'symbol': 'EOS/BTC',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'EOS/ETH': {'active': True,
#   'altname': 'EOSETH',
#   'base': 'EOS',
#   'baseId': 'EOS',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'EOSETH',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'EOSETH',
#    'base': 'EOS',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 6,
#    'quote': 'XETH'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 3.0},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 1e-06}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 6},
#   'quote': 'ETH',
#   'quoteId': 'XETH',
#   'symbol': 'EOS/ETH',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'EOS/EUR': {'active': True,
#   'altname': 'EOSEUR',
#   'base': 'EOS',
#   'baseId': 'EOS',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'EOSEUR',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'EOSEUR',
#    'base': 'EOS',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 4,
#    'quote': 'ZEUR'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 3.0},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 0.0001}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 4},
#   'quote': 'EUR',
#   'quoteId': 'ZEUR',
#   'symbol': 'EOS/EUR',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'EOS/USD': {'active': True,
#   'altname': 'EOSUSD',
#   'base': 'EOS',
#   'baseId': 'EOS',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'EOSUSD',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'EOSUSD',
#    'base': 'EOS',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 4,
#    'quote': 'ZUSD'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 3.0},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 0.0001}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 4},
#   'quote': 'USD',
#   'quoteId': 'ZUSD',
#   'symbol': 'EOS/USD',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'ETC/BTC': {'active': True,
#   'altname': 'ETCXBT',
#   'base': 'ETC',
#   'baseId': 'XETC',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'XETCXXBT',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'ETCXBT',
#    'base': 'XETC',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [2, 3],
#    'leverage_sell': [2, 3],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 6,
#    'quote': 'XXBT'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 0.3},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 1e-06}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 6},
#   'quote': 'BTC',
#   'quoteId': 'XXBT',
#   'symbol': 'ETC/BTC',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'ETC/ETH': {'active': True,
#   'altname': 'ETCETH',
#   'base': 'ETC',
#   'baseId': 'XETC',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'XETCXETH',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'ETCETH',
#    'base': 'XETC',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [2],
#    'leverage_sell': [2],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 6,
#    'quote': 'XETH'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 0.3},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 1e-06}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 6},
#   'quote': 'ETH',
#   'quoteId': 'XETH',
#   'symbol': 'ETC/ETH',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'ETC/EUR': {'active': True,
#   'altname': 'ETCEUR',
#   'base': 'ETC',
#   'baseId': 'XETC',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'XETCZEUR',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'ETCEUR',
#    'base': 'XETC',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [2],
#    'leverage_sell': [2],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 3,
#    'quote': 'ZEUR'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 0.3},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 0.001}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 3},
#   'quote': 'EUR',
#   'quoteId': 'ZEUR',
#   'symbol': 'ETC/EUR',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'ETC/USD': {'active': True,
#   'altname': 'ETCUSD',
#   'base': 'ETC',
#   'baseId': 'XETC',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'XETCZUSD',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'ETCUSD',
#    'base': 'XETC',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [2],
#    'leverage_sell': [2],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 3,
#    'quote': 'ZUSD'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 0.3},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 0.001}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 3},
#   'quote': 'USD',
#   'quoteId': 'ZUSD',
#   'symbol': 'ETC/USD',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'ETH/BTC': {'active': True,
#   'altname': 'ETHXBT',
#   'base': 'ETH',
#   'baseId': 'XETH',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'XETHXXBT',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'ETHXBT',
#    'base': 'XETH',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [2, 3, 4, 5],
#    'leverage_sell': [2, 3, 4, 5],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 5,
#    'quote': 'XXBT'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 0.02},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 1e-05}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 5},
#   'quote': 'BTC',
#   'quoteId': 'XXBT',
#   'symbol': 'ETH/BTC',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'ETH/CAD': {'active': True,
#   'altname': 'ETHCAD',
#   'base': 'ETH',
#   'baseId': 'XETH',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'XETHZCAD',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'ETHCAD',
#    'base': 'XETH',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 2,
#    'quote': 'ZCAD'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 0.02},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 0.01}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 2},
#   'quote': 'CAD',
#   'quoteId': 'ZCAD',
#   'symbol': 'ETH/CAD',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'ETH/EUR': {'active': True,
#   'altname': 'ETHEUR',
#   'base': 'ETH',
#   'baseId': 'XETH',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'XETHZEUR',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'ETHEUR',
#    'base': 'XETH',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [2, 3, 4, 5],
#    'leverage_sell': [2, 3, 4, 5],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 2,
#    'quote': 'ZEUR'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 0.02},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 0.01}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 2},
#   'quote': 'EUR',
#   'quoteId': 'ZEUR',
#   'symbol': 'ETH/EUR',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'ETH/GBP': {'active': True,
#   'altname': 'ETHGBP',
#   'base': 'ETH',
#   'baseId': 'XETH',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'XETHZGBP',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'ETHGBP',
#    'base': 'XETH',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 2,
#    'quote': 'ZGBP'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 0.02},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 0.01}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 2},
#   'quote': 'GBP',
#   'quoteId': 'ZGBP',
#   'symbol': 'ETH/GBP',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'ETH/JPY': {'active': True,
#   'altname': 'ETHJPY',
#   'base': 'ETH',
#   'baseId': 'XETH',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'XETHZJPY',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'ETHJPY',
#    'base': 'XETH',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 0,
#    'quote': 'ZJPY'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 0.02},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 1.0}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 0},
#   'quote': 'JPY',
#   'quoteId': 'ZJPY',
#   'symbol': 'ETH/JPY',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'ETH/USD': {'active': True,
#   'altname': 'ETHUSD',
#   'base': 'ETH',
#   'baseId': 'XETH',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'XETHZUSD',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'ETHUSD',
#    'base': 'XETH',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [2, 3, 4, 5],
#    'leverage_sell': [2, 3, 4, 5],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 2,
#    'quote': 'ZUSD'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 0.02},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 0.01}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 2},
#   'quote': 'USD',
#   'quoteId': 'ZUSD',
#   'symbol': 'ETH/USD',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'ETHCAD.d': {'active': True,
#   'altname': 'ETHCAD.d',
#   'base': 'ETH',
#   'baseId': 'XETH',
#   'darkpool': True,
#   'fee_loaded': False,
#   'id': 'XETHZCAD.d',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'ETHCAD.d',
#    'base': 'XETH',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.36],
#     [50000, 0.34],
#     [100000, 0.32],
#     [250000, 0.3],
#     [500000, 0.28],
#     [1000000, 0.26],
#     [2500000, 0.24],
#     [5000000, 0.22],
#     [10000000, 0.2]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 5,
#    'quote': 'ZCAD'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 0.02},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 1e-05}},
#   'maker': None,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 5},
#   'quote': 'CAD',
#   'quoteId': 'ZCAD',
#   'symbol': 'ETHCAD.d',
#   'taker': 0.0036,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'ETHEUR.d': {'active': True,
#   'altname': 'ETHEUR.d',
#   'base': 'ETH',
#   'baseId': 'XETH',
#   'darkpool': True,
#   'fee_loaded': False,
#   'id': 'XETHZEUR.d',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'ETHEUR.d',
#    'base': 'XETH',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.36],
#     [50000, 0.34],
#     [100000, 0.32],
#     [250000, 0.3],
#     [500000, 0.28],
#     [1000000, 0.26],
#     [2500000, 0.24],
#     [5000000, 0.22],
#     [10000000, 0.2]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 5,
#    'quote': 'ZEUR'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 0.02},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 1e-05}},
#   'maker': None,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 5},
#   'quote': 'EUR',
#   'quoteId': 'ZEUR',
#   'symbol': 'ETHEUR.d',
#   'taker': 0.0036,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'ETHGBP.d': {'active': True,
#   'altname': 'ETHGBP.d',
#   'base': 'ETH',
#   'baseId': 'XETH',
#   'darkpool': True,
#   'fee_loaded': False,
#   'id': 'XETHZGBP.d',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'ETHGBP.d',
#    'base': 'XETH',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.36],
#     [50000, 0.34],
#     [100000, 0.32],
#     [250000, 0.3],
#     [500000, 0.28],
#     [1000000, 0.26],
#     [2500000, 0.24],
#     [5000000, 0.22],
#     [10000000, 0.2]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 5,
#    'quote': 'ZGBP'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 0.02},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 1e-05}},
#   'maker': None,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 5},
#   'quote': 'GBP',
#   'quoteId': 'ZGBP',
#   'symbol': 'ETHGBP.d',
#   'taker': 0.0036,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'ETHJPY.d': {'active': True,
#   'altname': 'ETHJPY.d',
#   'base': 'ETH',
#   'baseId': 'XETH',
#   'darkpool': True,
#   'fee_loaded': False,
#   'id': 'XETHZJPY.d',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'ETHJPY.d',
#    'base': 'XETH',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.36],
#     [50000, 0.34],
#     [100000, 0.32],
#     [250000, 0.3],
#     [500000, 0.28],
#     [1000000, 0.26],
#     [2500000, 0.24],
#     [5000000, 0.22],
#     [10000000, 0.2]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 3,
#    'quote': 'ZJPY'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 0.02},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 0.001}},
#   'maker': None,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 3},
#   'quote': 'JPY',
#   'quoteId': 'ZJPY',
#   'symbol': 'ETHJPY.d',
#   'taker': 0.0036,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'ETHUSD.d': {'active': True,
#   'altname': 'ETHUSD.d',
#   'base': 'ETH',
#   'baseId': 'XETH',
#   'darkpool': True,
#   'fee_loaded': False,
#   'id': 'XETHZUSD.d',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'ETHUSD.d',
#    'base': 'XETH',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.36],
#     [50000, 0.34],
#     [100000, 0.32],
#     [250000, 0.3],
#     [500000, 0.28],
#     [1000000, 0.26],
#     [2500000, 0.24],
#     [5000000, 0.22],
#     [10000000, 0.2]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 5,
#    'quote': 'ZUSD'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 0.02},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 1e-05}},
#   'maker': None,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 5},
#   'quote': 'USD',
#   'quoteId': 'ZUSD',
#   'symbol': 'ETHUSD.d',
#   'taker': 0.0036,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'ETHXBT.d': {'active': True,
#   'altname': 'ETHXBT.d',
#   'base': 'ETH',
#   'baseId': 'XETH',
#   'darkpool': True,
#   'fee_loaded': False,
#   'id': 'XETHXXBT.d',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'ETHXBT.d',
#    'base': 'XETH',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.36],
#     [50000, 0.34],
#     [100000, 0.32],
#     [250000, 0.3],
# ...
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'XMRUSD',
#    'base': 'XXMR',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [2],
#    'leverage_sell': [2],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 2,
#    'quote': 'ZUSD'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 0.1},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 0.01}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 2},
#   'quote': 'USD',
#   'quoteId': 'ZUSD',
#   'symbol': 'XMR/USD',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'XRP/BTC': {'active': True,
#   'altname': 'XRPXBT',
#   'base': 'XRP',
#   'baseId': 'XXRP',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'XXRPXXBT',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'XRPXBT',
#    'base': 'XXRP',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 8,
#    'quote': 'XXBT'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 30.0},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 1e-08}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 8},
#   'quote': 'BTC',
#   'quoteId': 'XXBT',
#   'symbol': 'XRP/BTC',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'XRP/CAD': {'active': True,
#   'altname': 'XRPCAD',
#   'base': 'XRP',
#   'baseId': 'XXRP',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'XXRPZCAD',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'XRPCAD',
#    'base': 'XXRP',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 5,
#    'quote': 'ZCAD'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 30.0},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 1e-05}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 5},
#   'quote': 'CAD',
#   'quoteId': 'ZCAD',
#   'symbol': 'XRP/CAD',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'XRP/EUR': {'active': True,
#   'altname': 'XRPEUR',
#   'base': 'XRP',
#   'baseId': 'XXRP',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'XXRPZEUR',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'XRPEUR',
#    'base': 'XXRP',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 5,
#    'quote': 'ZEUR'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 30.0},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 1e-05}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 5},
#   'quote': 'EUR',
#   'quoteId': 'ZEUR',
#   'symbol': 'XRP/EUR',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'XRP/JPY': {'active': True,
#   'altname': 'XRPJPY',
#   'base': 'XRP',
#   'baseId': 'XXRP',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'XXRPZJPY',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'XRPJPY',
#    'base': 'XXRP',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 3,
#    'quote': 'ZJPY'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 30.0},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 0.001}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 3},
#   'quote': 'JPY',
#   'quoteId': 'ZJPY',
#   'symbol': 'XRP/JPY',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'XRP/USD': {'active': True,
#   'altname': 'XRPUSD',
#   'base': 'XRP',
#   'baseId': 'XXRP',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'XXRPZUSD',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'XRPUSD',
#    'base': 'XXRP',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 5,
#    'quote': 'ZUSD'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 30.0},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 1e-05}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 5},
#   'quote': 'USD',
#   'quoteId': 'ZUSD',
#   'symbol': 'XRP/USD',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'ZEC/BTC': {'active': True,
#   'altname': 'ZECXBT',
#   'base': 'ZEC',
#   'baseId': 'XZEC',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'XZECXXBT',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'ZECXBT',
#    'base': 'XZEC',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 5,
#    'quote': 'XXBT'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 0.03},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 1e-05}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 5},
#   'quote': 'BTC',
#   'quoteId': 'XXBT',
#   'symbol': 'ZEC/BTC',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'ZEC/EUR': {'active': True,
#   'altname': 'ZECEUR',
#   'base': 'ZEC',
#   'baseId': 'XZEC',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'XZECZEUR',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'ZECEUR',
#    'base': 'XZEC',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 3,
#    'quote': 'ZEUR'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 0.03},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 0.001}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 3},
#   'quote': 'EUR',
#   'quoteId': 'ZEUR',
#   'symbol': 'ZEC/EUR',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'ZEC/JPY': {'active': True,
#   'altname': 'ZECJPY',
#   'base': 'ZEC',
#   'baseId': 'XZEC',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'XZECZJPY',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'ZECJPY',
#    'base': 'XZEC',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 3,
#    'quote': 'ZJPY'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 0.03},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 0.001}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 3},
#   'quote': 'JPY',
#   'quoteId': 'ZJPY',
#   'symbol': 'ZEC/JPY',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}},
#  'ZEC/USD': {'active': True,
#   'altname': 'ZECUSD',
#   'base': 'ZEC',
#   'baseId': 'XZEC',
#   'darkpool': False,
#   'fee_loaded': False,
#   'id': 'XZECZUSD',
#   'info': {'aclass_base': 'currency',
#    'aclass_quote': 'currency',
#    'altname': 'ZECUSD',
#    'base': 'XZEC',
#    'fee_volume_currency': 'ZUSD',
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'lot': 'unit',
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'margin_call': 80,
#    'margin_stop': 40,
#    'pair_decimals': 2,
#    'quote': 'ZUSD'},
#   'limits': {'amount': {'max': 100000000.0, 'min': 0.03},
#    'cost': {'max': None, 'min': 0},
#    'price': {'max': None, 'min': 0.01}},
#   'maker': 0.0016,
#   'percentage': True,
#   'precision': {'amount': 8, 'price': 2},
#   'quote': 'USD',
#   'quoteId': 'ZUSD',
#   'symbol': 'ZEC/USD',
#   'taker': 0.0026,
#   'tierBased': True,
#   'tiers': {'maker': [[0, 0.0016],
#     [50000, 0.0014],
#     [100000, 0.0012],
#     [250000, 0.001],
#     [500000, 0.0008],
#     [1000000, 0.0006],
#     [2500000, 0.0004],
#     [5000000, 0.0002],
#     [10000000, 0.0]],
#    'taker': [[0, 0.0026],
#     [50000, 0.0024],
#     [100000, 0.0022],
#     [250000, 0.002],
#     [500000, 0.0018],
#     [1000000, 0.0016],
#     [2500000, 0.0014],
#     [5000000, 0.0012],
#     [10000000, 0.0001]]}}}

# %%
kraken.markets['BTC/USD']
# Out:
# {'active': True,
#  'altname': 'XBTUSD',
#  'base': 'BTC',
#  'baseId': 'XXBT',
#  'darkpool': False,
#  'fee_loaded': False,
#  'id': 'XXBTZUSD',
#  'info': {'aclass_base': 'currency',
#   'aclass_quote': 'currency',
#   'altname': 'XBTUSD',
#   'base': 'XXBT',
#   'fee_volume_currency': 'ZUSD',
#   'fees': [[0, 0.26],
#    [50000, 0.24],
#    [100000, 0.22],
#    [250000, 0.2],
#    [500000, 0.18],
#    [1000000, 0.16],
#    [2500000, 0.14],
#    [5000000, 0.12],
#    [10000000, 0.1]],
#   'fees_maker': [[0, 0.16],
#    [50000, 0.14],
#    [100000, 0.12],
#    [250000, 0.1],
#    [500000, 0.08],
#    [1000000, 0.06],
#    [2500000, 0.04],
#    [5000000, 0.02],
#    [10000000, 0]],
#   'leverage_buy': [2, 3, 4, 5],
#   'leverage_sell': [2, 3, 4, 5],
#   'lot': 'unit',
#   'lot_decimals': 8,
#   'lot_multiplier': 1,
#   'margin_call': 80,
#   'margin_stop': 40,
#   'pair_decimals': 1,
#   'quote': 'ZUSD'},
#  'limits': {'amount': {'max': 100000000.0, 'min': 1e-08},
#   'cost': {'max': None, 'min': 0},
#   'price': {'max': None, 'min': 0.1}},
#  'maker': 0.0016,
#  'percentage': True,
#  'precision': {'amount': 8, 'price': 1},
#  'quote': 'USD',
#  'quoteId': 'ZUSD',
#  'symbol': 'BTC/USD',
#  'taker': 0.0026,
#  'tierBased': True,
#  'tiers': {'maker': [[0, 0.0016],
#    [50000, 0.0014],
#    [100000, 0.0012],
#    [250000, 0.001],
#    [500000, 0.0008],
#    [1000000, 0.0006],
#    [2500000, 0.0004],
#    [5000000, 0.0002],
#    [10000000, 0.0]],
#   'taker': [[0, 0.0026],
#    [50000, 0.0024],
#    [100000, 0.0022],
#    [250000, 0.002],
#    [500000, 0.0018],
#    [1000000, 0.0016],
#    [2500000, 0.0014],
#    [5000000, 0.0012],
#    [10000000, 0.0001]]}}
